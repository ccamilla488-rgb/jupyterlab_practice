# %% [markdown]
# # Camilla Cyr
#
# Notebook for Assignment 7

# %%
def compute_mean(values):
    mean = sum(values) / len(values)
    print(mean)

compute_mean([2, 4, 6, 8])
# Out:
# 5.0

# %% [markdown]
# The above code shows the mean of the values 2, 4, 6, and 8.
#
# $$
# \bar{x} = \frac{x_1+x_2+x_3+x_4}{n} = \frac{1}{n} \left( \sum_{i=1}^{n} x_i \right)
# $$
